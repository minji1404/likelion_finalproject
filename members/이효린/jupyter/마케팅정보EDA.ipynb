# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# 🔹 1. 기본 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
mpl.rcParams['axes.unicode_minus'] = False

# 🔹 2. 파일 경로 리스트 생성
base_path = "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/7.마케팅정보"
months = ['07', '08', '09', '10', '11', '12']
file_paths = [os.path.join(base_path, f"2018{month}_train_마케팅정보.parquet") for month in months]

# 🔹 3. 데이터 병합
df_list = []
for path in file_paths:
    temp = pd.read_parquet(path)
    temp['기준년월'] = os.path.basename(path).split('_')[0]
    df_list.append(temp)

df = pd.concat(df_list, ignore_index=True)

# 🔹 4. 기본 정보 확인
print("📌 데이터 크기:", df.shape)
print("\n📌 데이터 타입 및 결측치:")
print(df.info())
print("\n📌 기초 통계량:")
print(df.describe(include='all'))

# 🔹 5. 결측치 비율 확인
missing_ratio = df.isnull().mean().sort_values(ascending=False)
print("\n📌 결측치 비율 높은 순:")
print(missing_ratio[missing_ratio > 0])

# 🔹 6. 수치형 변수 시각화 (히스토그램)
numeric_cols = df.select_dtypes(include='number').columns
for col in numeric_cols:
    plt.figure(figsize=(6, 3))
    df[col].hist(bins=50)
    plt.title(f"{col} 분포")
    plt.xlabel(col)
    plt.ylabel("빈도")
    plt.tight_layout()
    plt.show()

# 🔹 7. 상관관계 분석
corr_matrix = df[numeric_cols].corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True)
plt.title("수치형 변수 간 상관관계 히트맵")
plt.tight_layout()
plt.show()

# 🔹 8. 이상치 탐색 (Boxplot 예시)
for col in numeric_cols:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=df[col])
    plt.title(f"{col} 이상치 탐색")
    plt.tight_layout()
    plt.show()
# Out:
# 📌 데이터 크기: (2400000, 64)
#
# 📌 데이터 타입 및 결측치:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2400000 entries, 0 to 2399999
# Data columns (total 64 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   기준년월               object
#  1   ID                 object
#  2   컨택건수_카드론_TM_B0M    int64
#  3   컨택건수_리볼빙_TM_B0M    int64
#  4   컨택건수_CA_TM_B0M     int64
#  5   컨택건수_이용유도_TM_B0M   int64
#  6   컨택건수_신용발급_TM_B0M   int64
#  7   컨택건수_부대서비스_TM_B0M  int64
#  8   컨택건수_포인트소진_TM_B0M  int64
#  9   컨택건수_보험_TM_B0M     int64
#  10  컨택건수_카드론_LMS_B0M   int64
#  11  컨택건수_CA_LMS_B0M    int64
#  12  컨택건수_리볼빙_LMS_B0M   int64
#  13  컨택건수_이용유도_LMS_B0M  int64
#  14  컨택건수_카드론_EM_B0M    int64
#  15  컨택건수_CA_EM_B0M     int64
#  16  컨택건수_리볼빙_EM_B0M    int64
#  17  컨택건수_이용유도_EM_B0M   int64
#  18  컨택건수_카드론_청구서_B0M   int64
#  19  컨택건수_CA_청구서_B0M    int64
#  20  컨택건수_리볼빙_청구서_B0M   int64
#  21  컨택건수_이용유도_청구서_B0M  int64
#  22  컨택건수_카드론_인터넷_B0M   int64
#  23  컨택건수_CA_인터넷_B0M    int64
#  24  컨택건수_리볼빙_인터넷_B0M   int64
#  25  컨택건수_이용유도_인터넷_B0M  int64
#  26  컨택건수_카드론_당사앱_B0M   int64
#  27  컨택건수_CA_당사앱_B0M    int64
#  28  컨택건수_리볼빙_당사앱_B0M   int64
#  29  컨택건수_이용유도_당사앱_B0M  int64
#  30  컨택건수_카드론_TM_R6M    int64
#  31  컨택건수_CA_TM_R6M     int64
#  32  컨택건수_리볼빙_TM_R6M    int64
#  33  컨택건수_이용유도_TM_R6M   int64
#  34  컨택건수_신용발급_TM_R6M   int64
#  35  컨택건수_부대서비스_TM_R6M  int64
#  36  컨택건수_포인트소진_TM_R6M  int64
#  37  컨택건수_보험_TM_R6M     int64
#  38  컨택건수_카드론_LMS_R6M   int64
#  39  컨택건수_CA_LMS_R6M    int64
#  40  컨택건수_리볼빙_LMS_R6M   int64
#  41  컨택건수_이용유도_LMS_R6M  int64
#  42  컨택건수_카드론_EM_R6M    int64
#  43  컨택건수_CA_EM_R6M     int64
#  44  컨택건수_리볼빙_EM_R6M    int64
#  45  컨택건수_이용유도_EM_R6M   int64
#  46  컨택건수_카드론_청구서_R6M   int64
#  47  컨택건수_CA_청구서_R6M    int64
#  48  컨택건수_리볼빙_청구서_R6M   int64
#  49  컨택건수_이용유도_청구서_R6M  int64
#  50  컨택건수_카드론_인터넷_R6M   int64
#  51  컨택건수_CA_인터넷_R6M    int64
#  52  컨택건수_리볼빙_인터넷_R6M   int64
#  53  컨택건수_이용유도_인터넷_R6M  int64
#  54  컨택건수_카드론_당사앱_R6M   int64
#  55  컨택건수_CA_당사앱_R6M    int64
#  56  컨택건수_리볼빙_당사앱_R6M   int64
#  57  컨택건수_이용유도_당사앱_R6M  int64
#  58  컨택건수_채권_B0M        int64
#  59  컨택건수_FDS_B0M       int64
#  60  컨택건수_채권_R6M        int64
#  61  컨택건수_FDS_R6M       int64
#  62  캠페인접촉건수_R12M       object
#  63  캠페인접촉일수_R12M       object
# dtypes: int64(60), object(4)
# memory usage: 1.1+ GB
# None
#
# 📌 기초 통계량:
#            기준년월            ID  컨택건수_카드론_TM_B0M  컨택건수_리볼빙_TM_B0M  \
# count   2400000       2400000     2.400000e+06     2.400000e+06
# unique        6        400000              NaN              NaN
# top      201807  TRAIN_000000              NaN              NaN
# freq     400000             6              NaN              NaN
# mean        NaN           NaN     1.657625e-01     6.666667e-06
# std         NaN           NaN     6.976548e-01     3.162271e-03
# min         NaN           NaN     0.000000e+00     0.000000e+00
# 25%         NaN           NaN     0.000000e+00     0.000000e+00
# 50%         NaN           NaN     0.000000e+00     0.000000e+00
# 75%         NaN           NaN     0.000000e+00     0.000000e+00
# max         NaN           NaN     4.000000e+00     2.000000e+00
#
#         컨택건수_CA_TM_B0M  컨택건수_이용유도_TM_B0M  컨택건수_신용발급_TM_B0M  컨택건수_부대서비스_TM_B0M  \
# count        2400000.0      2.400000e+06      2.400000e+06       2.400000e+06
# unique             NaN               NaN               NaN                NaN
# top                NaN               NaN               NaN                NaN
# freq               NaN               NaN               NaN                NaN
# mean               0.0      7.920292e-02      2.500000e-06       4.166667e-07
# std                0.0      4.768350e-01      1.581137e-03       6.454972e-04
# min                0.0      0.000000e+00      0.000000e+00       0.000000e+00
# 25%                0.0      0.000000e+00      0.000000e+00       0.000000e+00
# 50%                0.0      0.000000e+00      0.000000e+00       0.000000e+00
# 75%                0.0      0.000000e+00      0.000000e+00       0.000000e+00
# max                0.0      3.000000e+00      1.000000e+00       1.000000e+00
#
#         컨택건수_포인트소진_TM_B0M  컨택건수_보험_TM_B0M  ...  컨택건수_카드론_당사앱_R6M  \
# count           2400000.0    2.400000e+06  ...         2400000.0
# unique                NaN             NaN  ...               NaN
# top                   NaN             NaN  ...               NaN
# freq                  NaN             NaN  ...               NaN
# mean                  0.0    1.316500e-02  ...               0.0
# std                   0.0    1.139811e-01  ...               0.0
# min                   0.0    0.000000e+00  ...               0.0
# 25%                   0.0    0.000000e+00  ...               0.0
# 50%                   0.0    0.000000e+00  ...               0.0
# 75%                   0.0    0.000000e+00  ...               0.0
# max                   0.0    1.000000e+00  ...               0.0
#
#         컨택건수_CA_당사앱_R6M  컨택건수_리볼빙_당사앱_R6M  컨택건수_이용유도_당사앱_R6M   컨택건수_채권_B0M  \
# count         2400000.0         2400000.0       2.400000e+06  2.400000e+06
# unique              NaN               NaN                NaN           NaN
# top                 NaN               NaN                NaN           NaN
# freq                NaN               NaN                NaN           NaN
# mean                0.0               0.0       7.004167e-04  2.744625e-02
# std                 0.0               0.0       4.600645e-02  3.823193e-01
# min                 0.0               0.0       0.000000e+00  0.000000e+00
# 25%                 0.0               0.0       0.000000e+00  0.000000e+00
# 50%                 0.0               0.0       0.000000e+00  0.000000e+00
# 75%                 0.0               0.0       0.000000e+00  0.000000e+00
# max                 0.0               0.0       4.000000e+00  8.000000e+00
#
#         컨택건수_FDS_B0M   컨택건수_채권_R6M  컨택건수_FDS_R6M  캠페인접촉건수_R12M  캠페인접촉일수_R12M
# count      2400000.0  2.400000e+06     2400000.0       2400000       2400000
# unique           NaN           NaN           NaN             6             5
# top              NaN           NaN           NaN         1회 이상         1일 이상
# freq             NaN           NaN           NaN       1719595       1754523
# mean             0.0  4.281692e-01           0.0           NaN           NaN
# std              0.0  2.160925e+00           0.0           NaN           NaN
# min              0.0  0.000000e+00           0.0           NaN           NaN
# 25%              0.0  0.000000e+00           0.0           NaN           NaN
# 50%              0.0  0.000000e+00           0.0           NaN           NaN
# 75%              0.0  0.000000e+00           0.0           NaN           NaN
# max              0.0  3.900000e+01           0.0           NaN           NaN
#
# [11 rows x 64 columns]
#
# 📌 결측치 비율 높은 순:
# Series([], dtype: float64)
# C:\Users\HR\AppData\Local\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
import pandas as pd
import os

# 🔹 1. 기본 설정
credit_base_path = "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/7.마케팅정보"
member_base_path = "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/1.회원정보"
months = ['07', '08', '09', '10', '11', '12']

# 🔹 2. 병합용 데이터 저장 리스트
merged_list = []

for month in months:
    ym = f"2018{month}"

    # 신용정보 파일
    credit_path = os.path.join(credit_base_path, f"{ym}_train_마케팅정보.parquet")
    credit_df = pd.read_parquet(credit_path)
    credit_df["기준년월"] = ym

    # 회원정보 파일
    member_path = os.path.join(member_base_path, f"{ym}_train_회원정보.parquet")
    member_df = pd.read_parquet(member_path)
    member_df = member_df[["ID", "기준년월", "Segment"]].copy()
    member_df["기준년월"] = ym

    # 병합
    merged = pd.merge(credit_df, member_df, on=["ID", "기준년월"], how="left")
    merged_list.append(merged)

# 🔹 3. 전체 병합
final_df = pd.concat(merged_list, ignore_index=True)

# 🔹 4. 확인
print("✅ 병합 완료 | 데이터 크기:", final_df.shape)
print(final_df[['ID', '기준년월', 'Segment']].head())
print(final_df['Segment'].value_counts(dropna=False))
# Out:
# ✅ 병합 완료 | 데이터 크기: (2400000, 65)
#              ID    기준년월 Segment
# 0  TRAIN_000000  201807       D
# 1  TRAIN_000001  201807       E
# 2  TRAIN_000002  201807       C
# 3  TRAIN_000003  201807       D
# 4  TRAIN_000004  201807       E
# Segment
# E    1922052
# D     349242
# C     127590
# A        972
# B        144
# Name: count, dtype: int64

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import matplotlib as mpl

# 🔹 경로 설정
credit_base_path = "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/7.마케팅정보"
member_base_path = "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/1.회원정보"
months = ['07', '08', '09', '10', '11', '12']

# 🔹 데이터 병합
merged_list = []

for month in months:
    ym = f"2018{month}"

    credit_path = os.path.join(credit_base_path, f"{ym}_train_마케팅정보.parquet")
    credit_df = pd.read_parquet(credit_path)
    credit_df["기준년월"] = ym

    member_path = os.path.join(member_base_path, f"{ym}_train_회원정보.parquet")
    member_df = pd.read_parquet(member_path)
    member_df = member_df[["ID", "기준년월", "Segment"]].copy()
    member_df["기준년월"] = ym

    merged = pd.merge(credit_df, member_df, on=["ID", "기준년월"], how="left")
    merged_list.append(merged)

# 🔹 최종 병합 DataFrame
final_df = pd.concat(merged_list, ignore_index=True)

# 🔹 수치형 변수만 추출 (Segment 제외)
numeric_cols = final_df.select_dtypes(include='number').columns.drop('Segment', errors='ignore')

# 🔹 Segment별 평균 계산
group_summary = final_df.groupby('Segment')[numeric_cols].mean(numeric_only=True)

# 🔹 시각화: Jupyter에 보기 좋게 출력 (선택사항)
from IPython.display import display

plt.rcParams['font.family'] = 'Malgun Gothic'
mpl.rcParams['axes.unicode_minus'] = False

display(group_summary.style
        .background_gradient(cmap='YlGnBu')
        .set_caption("📊 Segment별 수치형 변수 평균값 요약")
        .format(precision=2))

# 🔹 이미지 파일로 저장
fig, ax = plt.subplots(figsize=(len(group_summary.columns) * 0.6 + 2, len(group_summary) * 0.6 + 1))
ax.axis('off')

table = ax.table(cellText=group_summary.round(2).values,
                 colLabels=group_summary.columns,
                 rowLabels=group_summary.index,
                 cellLoc='center',
                 loc='center')

table.auto_set_font_size(False)
table.set_fontsize(9)  # ✅ 오타 수정됨
table.scale(1.2, 1.2)

plt.title("📊 Segment별 수치형 변수 평균값 요약", fontsize=14, pad=20)
plt.savefig("마케팅_segment_summary_table.png", dpi=300, bbox_inches='tight')
plt.close()

print("✅ 테이블 이미지 저장 완료: 마케팅_segment_summary_table.png")
# Out:
# <style type="text/css">
# #T_70f72_row0_col0, #T_70f72_row0_col1, #T_70f72_row0_col2, #T_70f72_row0_col3, #T_70f72_row0_col4, #T_70f72_row0_col5, #T_70f72_row0_col6, #T_70f72_row0_col8, #T_70f72_row0_col9, #T_70f72_row0_col10, #T_70f72_row0_col13, #T_70f72_row0_col14, #T_70f72_row0_col16, #T_70f72_row0_col18, #T_70f72_row0_col20, #T_70
{
#   background-color: #76cabc;
#   color: #000000;
# }
# #T_70f72_row2_col23 {
#   background-color: #2397c1;
#   color: #f1f1f1;
# }
# #T_70f72_row2_col28 {
#   background-color: #63c3bf;
#   color: #000000;
# }
# #T_70f72_row2_col31 {
#   background-color: #dcf1b2;
#   color: #000000;
# }
# #T_70f72_row2_col32 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_70f72_row2_col33, #T_70f72_row3_col40 {
#   background-color: #f0f9b8;
#   color: #000000;
# }
# #T_70f72_row2_col34 {
#   background-color: #32a6c2;
#   color: #f1f1f1;
# }
# #T_70f72_row2_col35 {
#   background-color: #fdfed4;
#   color: #000000;
# }
# #T_70f72_row2_col36, #T_70f72_row2_col51 {
#   background-color: #4ebbc2;
#   color: #000000;
# }
# #T_70f72_row2_col38 {
#   background-color: #225ca7;
#   color: #f1f1f1;
# }
# #T_70f72_row2_col39, #T_70f72_row2_col40, #T_70f72_row3_col3 {
#   background-color: #f1faba;
#   color: #000000;
# }
# #T_70f72_row2_col43, #T_70f72_row2_col45 {
#   background-color: #5bc0c0;
#   color: #000000;
# }
# #T_70f72_row2_col56 {
#   background-color: #1f2f87;
#   color: #f1f1f1;
# }
# #T_70f72_row2_col58 {
#   background-color: #253595;
#   color: #f1f1f1;
# }
# #T_70f72_row3_col10 {
#   background-color: #d9f0b3;
#   color: #000000;
# }
# #T_70f72_row3_col16 {
#   background-color: #1e8bbd;
#   color: #f1f1f1;
# }
# #T_70f72_row3_col17 {
#   background-color: #2262aa;
#   color: #f1f1f1;
# }
# #T_70f72_row3_col19 {
#   background-color: #b7e3b6;
#   color: #000000;
# }
# #T_70f72_row3_col23, #T_70f72_row3_col45 {
#   background-color: #234b9f;
#   color: #f1f1f1;
# }
# #T_70f72_row3_c
# C:\Users\HR\AppData\Local\Temp\ipykernel_21176\735380170.py:64: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) Malgun Gothic.
#   plt.savefig("마케팅_segment_summary_table.png", dpi=300, bbox_inches='tight')
# ✅ 테이블 이미지 저장 완료: 마케팅_segment_summary_table.png

# %%
print("Segment 분포:")
print(final_df['Segment'].value_counts())
# Out:
# Segment 분포:
# Segment
# E    1922052
# D     349242
# C     127590
# A        972
# B        144
# Name: count, dtype: int64

# %% [markdown]
# | Segment | 고객 수      | 비중 (대략)    | 특이사항                 |
# | ------- | --------- | ---------- | -------------------- |
# | E       | 1,922,052 | **85% 이상** | 대부분의 고객이 몰려 있음 (압도적) |
# | D       | 349,242   | 약 15%      | 준다수, 비교적 안정적인 비중     |
# | C       | 127,590   | 소수         | 데이터적으로 의미는 있지만 적음    |
# | A       | 972       | 극소수        | **VIP 또는 특수 고객** 가능성 |
# | B       | 144       | 극소수        | **리스크 고객** 가능성       |

# %% [markdown]
# | 주요 지표     | A          | B    | C    | D    | E              | 해석 요약                 |
# | --------- | ---------- | ---- | ---- | ---- | -------------- | --------------------- |
# | 마케팅수신동의율  | 0.79       | 0.79 | 0.78 | 0.73 | 0.62           | A, B > C > D > E      |
# | 마케팅수신거절횟수 | 낮음         | 낮음   | 낮음   | 낮음   | **높음**         | **E가 수신 거부 경험 가장 많음** |
# | DM수신거절횟수  | 낮음         | 낮음   | 낮음   | 낮음   | **높음**         | 직접 광고 차단 성향 강함        |
# | 텔레마케팅거절횟수 | 0.00\~0.03 | 0.00 | 0.00 | 0.00 | **최고치 (0.04)** | TM도 거절 경향 ↑           |

# %%
# Segment별 결측 비율 계산 함수
def segmentwise_missing_ratio(df, group_col='Segment'):
    result = (
        df.groupby(group_col)
        .apply(lambda g: g.isnull().mean())
        .T  # 변수 기준으로 보기 좋게 전치
    )
    return result

# 실행
missing_by_segment = segmentwise_missing_ratio(final_df)

# 시각적으로 보기 좋게 표시
from IPython.display import display

display(missing_by_segment.style
        .format("{:.2%}")
        .background_gradient(cmap="Oranges")
        .set_caption("📌 Segment별 결측치 비율"))
# Out:
# C:\Users\HR\AppData\Local\Temp\ipykernel_21176\336228968.py:5: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: g
#T_ac306_row23_col1, #T_ac306_row23_col2, #T_ac306_row23_col3, #T_ac306_row23_col4, #T_ac306_row24_col0, #T_ac306_row24_col1, #T_ac306_row24_col2, #T_ac306_row24_col3, #T_ac306_row24_col4, #T_ac306_row25_col0, #T_ac306_row25_col1, #T_ac306_row25_col2, #T_ac306_row25_col3, #T_ac306_row25_col4, #T_ac306_row26_col0, #T_ac306_row26_col1, #T_ac306_row26_col2, #T_ac306_row26_col3, #T_ac306_row26_col4, #T_ac306_row27_col0, #T_ac306_row27_col1, #T_ac306_row27_col2, #T_ac306_row27_col3, #T_ac306_row27_col4, #T_ac306_row28_col0, #T_ac306_row28_col1, #T_ac306_row28_col2, #T_ac306_row28_col3, #T_ac306_row28_col4, #T_ac306_row29_col0, #T_ac306_row29_col1, #T_ac306_row29_col2, #T_ac306_row29_col3, #T_ac306_row29_col4, #T_ac306_row30_col0, #T_ac306_row30_col1, #T_ac306_row30_col2, #T_ac306_row30_col3, #T_ac306_row30_col4, #T_ac306_row31_col0, #T_ac306_row31_col1, #T_ac306_row31_col2, #T_ac306_row31_col3, #T_ac306_row31_col4, #T_ac306_row32_col0, #T_ac306_row32_col1, #T_ac306_row32_col2, #T_ac306_row32_col3, #T_ac306_row32_col4, #T_ac306_row33_col0, #T_ac306_row33_col1, #T_ac306_row33_col2, #T_ac306_row33_col3, #T_ac306_row33_col4, #T_ac306_row34_col0, #T_ac306_row34_col1, #T_ac306_row34_col2, #T_ac306_row34_col3, #T_ac306_row34_col4, #T_ac306_row35_col0, #T_ac306_row35_col1, #T_ac306_row35_col2, #T_ac306_row35_col3, #T_ac306_row35_col4, #T_ac306_row36_col0, #T_ac306_row36_col1, #T_ac306_row36_col2, #T_ac306_row36_col3, #T_ac306_row36_col4, #T_ac306_row37_col0, #T_ac306_row37_col1, #T_ac306_row37_col2, #T_ac306_row37_col3, #T_ac306_row37_col4, #T_ac306_row38_col0, #T_ac306_row38_col1, #T_ac306_row38_col ...
#   background-color: #fff5eb;
#   color: #000000;
# }
# </style>
# <table id="T_ac306">
#   <caption>📌 Segment별 결측치 비율</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Segment</th>
#       <th id="T_ac306_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_ac306_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_ac306_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_ac306_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_ac306_level0_col4" class="col_heading level0 col4" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac306_level0_row0" class="row_heading level0 row0" >기준년월</th>
#       <td id="T_ac306_row0_col0" class="data row0 col0" >0.00%</td>
#       <td id="T_ac306_row0_col1" class="data row0 col1" >0.00%</td>
#       <td id="T_ac306_row0_col2" class="data row0 col2" >0.00%</td>
#       <td id="T_ac306_row0_col3" class="data row0 col3" >0.00%</td>
#       <td id="T_ac306_row0_col4" class="data row0 col4" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_ac306_level0_row1" class="row_heading level0 row1" >ID</th>
#       <td id="T_ac306_row1_col0" class="data row1 col0" >0.00%</td>
#       <td id="T_a

# %%
import numpy as np

# 수치형 변수만 대상으로
numeric_cols = final_df.select_dtypes(include='number').columns.drop('Segment', errors='ignore')

# 이상치 비율 계산 함수 (IQR 기준)
def segmentwise_outlier_ratio(df, group_col='Segment', cols=None):
    if cols is None:
        cols = df.select_dtypes(include='number').columns.drop('Segment', errors='ignore')

    result = pd.DataFrame(index=cols)

    for seg, group in df.groupby(group_col):
        outlier_ratio = []
        for col in cols:
            q1 = group[col].quantile(0.25)
            q3 = group[col].quantile(0.75)
            iqr = q3 - q1
            lower = q1 - 1.5 * iqr
            upper = q3 + 1.5 * iqr
            outliers = group[(group[col] < lower) | (group[col] > upper)]
            ratio = len(outliers) / len(group)
            outlier_ratio.append(ratio)
        result[seg] = outlier_ratio

    return result.T  # Segment가 index가 되도록 전치

# 실행
outlier_by_segment = segmentwise_outlier_ratio(final_df, cols=numeric_cols)

# 시각적으로 보기 좋게 표시
display(outlier_by_segment.style
        .format("{:.2%}")
        .background_gradient(cmap="Reds")
        .set_caption("📌 Segment별 이상치 비율 (IQR 기준)"))
# Out:
# <style type="text/css">
# #T_f2a78_row0_col0, #T_f2a78_row0_col1, #T_f2a78_row0_col2, #T_f2a78_row0_col3, #T_f2a78_row0_col4, #T_f2a78_row0_col5, #T_f2a78_row0_col6, #T_f2a78_row0_col8, #T_f2a78_row0_col9, #T_f2a78_row0_col10, #T_f2a78_row0_col11, #T_f2a78_row0_col13, #T_f2a78_row0_col14, #T_f2a78_row0_col16, #T_f2a78_row0_col18, #T_f2a78_row0_col19, #T_f2a78_row0_col20, #T_f2a78_row0_col21, #T_f2a78_row0_col22, #T_f2a78_row0_col24, #T_f2a78_row0_col25, #T_f2a78_row0_col26, #T_f2a78_row0_col27, #T_f2a78_row0_col28, #T_f2a78_row0_col32, #T_f2a78_row0_col33, #T_f2a78_row0_col34, #T_f2a78_row0_col36, #T_f2a78_row0_col39, #T_f2a78_row0_col41, #T_f2a78_row0_col42, #T_f2a78_row0_col46, #T_f2a78_row0_col48, #T_f2a78_row0_col49, #T_f2a78_row0_col50, #T_f2a78_row0_col51, #T_f2a78_row0_col52, #T_f2a78_row0_col53, #T_f2a78_row0_col54, #T_f2a78_row0_col55, #T_f2a78_row0_col57, #T_f2a78_row0_col59, #T_f2a78_row1_col1, #T_f2a78_row1_col2, #T_f2a78_row1_col3, #T_f2a78_row1_col4, #T_f2a78_row1_col5, #T_f2a78_row1_col6, #T_f2a78_row1_col8, #T_f2a78_row1_col9, #T_f2a78_row1_col10, #T_f2a78_row1_col11, #T_f2a78_row1_col12, #T_f2a78_row1_col13, #T_f2a78_row1_col14, #T_f2a78_row1_col15, #T_f2a78_row1_col16, #T_f2a78_row1_col17, #T_f2a78_row1_col18, #T_f2a78_row1_col19, #T_f2a78_row1_col20, #T_f2a78_row1_col21, #T_f2a78_row1_col22, #T_f2a78_row1_col23, #T_f2a78_row1_col24, #T_f2a78_row1_col25, #T_f2a78_row1_col26, #T_f2a78_row1_col27, #T_f2a78_row1_col29, #T_f2a78_row1_col32, #T_f2a78_row1_col38, #T_f2a78_row1_col39, #T_f2a78_row1_col41, #T_f2a78_row1_col42, #T_f2a78_row1_col43, #T_f2a78_row1_col46, #T_f2a78_row1_col48, #T_f2a78_row1_col49, #T_f2a78_row1_col50, #T_f2a78_row1_col51, #T_f2a78_row1_col52, #T_f2a78_row1_col53, #T_f2a78_row1_col54, #T_f2a78_row1_col55, #
{
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_f2a78_row0_col12, #T_f2a78_row0_col17, #T_f2a78_row0_col23, #T_f2a78_row0_col29, #T_f2a78_row0_col30, #T_f2a78_row0_col45, #T_f2a78_row0_col47, #T_f2a78_row1_col7, #T_f2a78_row1_col33, #T_f2a78_row1_col34, #T_f2a78_row1_col36, #T_f2a78_row1_col40, #T_f2a78_row1_col44, #T_f2a78_row2_col1, #T_f2a78_row2_col10, #T_f2a78_row2_col16, #T_f2a78_row2_col27, #T_f2a78_row2_col55, #T_f2a78_row2_col58, #T_f2a78_row3_col0, #T_f2a78_row3_col8, #T_f2a78_row3_col9, #T_f2a78_row3_col15, #T_f2a78_row3_col31, #T_f2a78_row3_col35, #T_f2a78_row3_col38, #T_f2a78_row3_col56, #T_f2a78_row4_col3, #T_f2a78_row4_col4, #T_f2a78_row4_col5, #T_f2a78_row4_col28, #T_f2a78_row4_col32, #T_f2a78_row4_col37, #T_f2a78_row4_col39, #T_f2a78_row4_col43 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_f2a78_row0_col15, #T_f2a78_row4_col16 {
#   background-color: #9a0c14;
#   color: #f1f1f1;
# }
# #T_f2a78_row0_col31 {
#   background-color: #fdcbb6;
#   color: #000000;
# }
# #T_f2a78_row0_col35, #T_f2a78_row2_col35 {
#   background-color: #800610;
#   color: #f1f1f1;
# }
# #T_f2a78_row0_col37 {
#   background-color: #fca082;
#   color: #000000;
# }
# #T_f2a78_row0_col38 {
#   background-color: #c1161b;
#   color: #f1f1f1;
# }
# #T_f2a78_row0_col40 {
#   background-color: #fc9d7f;
#   color: #000000;
# }
# #T_f2a78_row0_col43 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_f2a78_row0_col44 {
#   background-color: #fc997a;
#   color: #000000;
# }
# #T_f2a78_row0_col56, #T_f2a78_row3_col43 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_f2a78_row0_col58 {
#   background-color: #a60f15;
#   color: #f1f1f1;
# }
# #T_f2a78_row1_col0 {
#   background-color: #fc8b6b;
#   color: #f1f1f1;
# }
# #T_f2a78_row1_col28 {
#   background-color: #c9181d;
#   color: #f1f1f1;
# }
# #T_f2a78_row1_col30 {
#   background-color: #920a13;
#   color: #f1f1f1;
# }
# #T_f2a78_row1_col31, #T_f2a78_row3_col37 {
#   background-color: #8c0912;
#   color: #f1f1f1;
# }
# #T_f2a78_row1_col35 {
#   background-color: #f85f43;
#   color: #f1f1f1;
# }
# #T_f2a78_row1_col37, #T_f2a78_row2_col3, #T_f2a78_row3_col12 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_f2a78_row1_col45 {
#   background-color: #fca98c;
#   color: #000000;
# }
# #T_f2a78_row1_col47 {
#   background-color: #b11218;
#   color: #f1f1f1;
# }
# #T_f2a78_row1_col58 {
#   background-color: #ad1117;
#   color: #f1f1f1;
# }
# #T_f2a78_row2_col0 {
#   background-color: #d42121;
#   color: #f1f1f1;
# }
# #T_f2a78_row2_col8 {
#   background-color: #fb7050;
#   color: #f1f1f1;
# }
# #T_f2a78_row2_col9, #T_f2a78_row3_col29 {
#   background-color: #fc8d6d;
#   color: #f1f1f1;
# }
# #T_f2a78_row2_col12 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_f2a78_row2_col15 {
#   background-color: #820711;
#   color: #f1f1f1;
# }
# #T_f2a78_row2_col17, #T_f2a78_row3_col34 {
#   background-color: #f5523a;
#   color: #f1f1f1;
# }
# #T_f2a78_row2_col23 {
#   background-color: #f14331;
#   color: #f1f1f1;
# }
# #T_f2a78_row2_col28 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_f2a78_row2_col29 {
#   background-color: #fc8666;
#   color: #f1f1f1;
# }
# #T_f2a78_row2_col31 {
#   background-color: #f03d2d;
#   color: #f1f1f1;
# }
# #T_f2a78_row2_col32 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_f2a78_row2_col33 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_f2a78_row2_col34 {
#   background-color: #f6563d;
#   color: #f1f1f1;
# }
# #T_f2a78_row2_col36 {
#   background-color: #fc8767;
#   color: #f1f1f1;
# }
# #T_f2a78_row2_col38 {
#   background-color: #bf151b;
#   color: #f1f1f1;
# }
# #T_f2a78_row2_col39 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_f2a78_row2_col40, #T_f2a78_row3_col3 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_f2a78_row2_col43 {
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_f2a78_row2_col45 {
#   background-color: #fb7555;
#   color: #f1f1f1;
# }
# #T_f2a78_row2_col47 {
#   background-color: #fc8464;
#   color: #f1f1f1;
# }
# #T_f2a78_row2_col56 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
# }
# #T_f2a78_row3_col10, #T_f2a78_row4_col33 {
#   background-color: #fdccb8;
#   color: #000000;
# }
# #T_f2a78_row3_col16 {
#   background-color: #eb372a;
#   color: #f1f1f1;
# }
# #T_f2a78_row3_col17 {
#   background-color: #ce1a1e;
#   color: #f1f1f1;
# }
# #T_f2a78_row3_col23 {
#   background-color: #b91419;
#   color: #f1f1f1;
# }
# #T

# %%
# 전체 결측 비율
missing_ratio_total = final_df.isnull().mean()

# 30% 이상 결측 컬럼 목록
high_missing_cols = missing_ratio_total[missing_ratio_total >= 0.3].index.tolist()

print(f"❌ 제거할 컬럼 수: {len(high_missing_cols)}")
print(high_missing_cols)

# 제거
df_cleaned = final_df.drop(columns=high_missing_cols)
# Out:
# ❌ 제거할 컬럼 수: 0
# []

# %%
# 수치형 변수 재정의
numeric_cols = df_cleaned.select_dtypes(include='number').columns.drop('Segment', errors='ignore')

# Segment별 평균값 요약
group_summary = df_cleaned.groupby('Segment')[numeric_cols].mean(numeric_only=True)

from IPython.display import display
display(group_summary.style
        .background_gradient(cmap='YlGnBu')
        .set_caption("📊 결측 제거 후 Segment별 평균값 요약")
        .format(precision=2))
# Out:
# <style type="text/css">
{
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_e0dcf_row0_col15, #T_e0dcf_row2_col29 {
#   background-color: #6fc7bd;
#   color: #000000;
# }
# #T_e0dcf_row0_col19 {
#   background-color: #152772;
#   color: #f1f1f1;
# }
# #T_e0dcf_row0_col37 {
#   background-color: #97d6b9;
#   color: #000000;
# }
# #T_e0dcf_row0_col38 {
#   background-color: #1b2c80;
#   color: #f1f1f1;
# }
# #T_e0dcf_row0_col39 {
#   background-color: #e2f4b2;
#   color: #000000;
# }
# #T_e0dcf_row0_col40, #T_e0dcf_row3_col47 {
#   background-color: #85cfba;
#   color: #000000;
# }
# #T_e0dcf_row0_col43 {
#   background-color: #73c8bd;
#   color: #000000;
# }
# #T_e0dcf_row0_col44 {
#   background-color: #78cbbc;
#   color: #000000;
# }
# #T_e0dcf_row0_col51 {
#   background-color: #2fa4c2;
#   color: #f1f1f1;
# }
# #T_e0dcf_row0_col56, #T_e0dcf_row3_col11 {
#   background-color: #e7f6b1;
#   color: #000000;
# }
# #T_e0dcf_row1_col0 {
#   background-color: #2da2c2;
#   color: #f1f1f1;
# }
# #T_e0dcf_row1_col28 {
#   background-color: #33a7c2;
#   color: #f1f1f1;
# }
# #T_e0dcf_row1_col30 {
#   background-color: #142670;
#   color: #f1f1f1;
# }
# #T_e0dcf_row1_col31 {
#   background-color: #a5dcb7;
#   color: #000000;
# }
# #T_e0dcf_row1_col37, #T_e0dcf_row2_col3, #T_e0dcf_row3_col12 {
#   background-color: #fafdce;
#   color: #000000;
# }
# #T_e0dcf_row1_col45 {
#   background-color: #c9eab4;
#   color: #000000;
# }
# #T_e0dcf_row1_col47 {
#   background-color: #2b9fc2;
#   color: #f1f1f1;
# }
# #T_e0dcf_row1_col58, #T_e0dcf_row4_col29 {
#   background-color: #c4e8b4;
#   color: #000000;
# }
# #T_e0dcf_row2_col0 {
#   background-color: #216bae;
#   color: #f1f1f1;
# }
# #T_e0dcf_row2_col8, #T_e0dcf_row3_col15 {
#   background-color: #4ab9c3;
#   color: #f1f1f1;
# }
# #T_e0dcf_row2_col9 {
#   background-color: #69c5be;
#   color: #000000;
# }
# #T_e0dcf_row2_col11, #T_e0dcf_row2_col47 {
#   background-color: #ddf2b2;
#   color: #000000;
# }
# #T_e0dcf_row2_col12 {
#   background-color: #f9fdcc;
#   color: #000000;
# }
# #T_e0dcf_row2_col15 {
#   background-color: #5fc1c0;
#   color: #000000;
# }
# #T_e0dcf_row2_col17, #T_e0dcf_row3_col34 {
#   background-color: #2ea3c2;
#   color: #f1f1f1;
# }
# #T_e0dcf_row2_col19, #T_e0dcf_row3_col29 {
#   background-color: #76cabc;
#   color: #000000;
# }
# #T_e0dcf_row2_col23 {
#   background-color: #2397c1;
#   color: #f1f1f1;
# }
# #T_e0dcf_row2_col28 {
#   background-color: #63c3bf;
#   color: #000000;
# }
# #T_e0dcf_row2_col31 {
#   background-color: #dcf1b2;
#   color: #000000;
# }
# #T_e0dcf_row2_col32 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_e0dcf_row2_col33, #T_e0dcf_row3_col40 {
#   background-color: #f0f9b8;
#   color: #000000;
# }
# #T_e0dcf_row2_col34 {
#   background-color: #32a6c2;
#   color: #f1f1f1;
# }
# #T_e0dcf_row2_col35 {
#   background-color: #fdfed4;
#   color: #000000;
# }
# #T_e0dcf_row2_col36, #T_e0dcf_row2_col51 {
#   background-color: #4ebbc2;
#   color: #000000;
# }
# #T_e0dcf_row2_col38 {
#   background-color: #225ca7;
#   color: #f1f1f1;
# }
# #T_e0dcf_row2_col39, #T_e0dcf_row2_col40, #T_e0dcf_row3_col3 {
#   background-color: #f1faba;
#   color: #000000;
# }
# #T_e0dcf_row2_col43, #T_e0dcf_row2_col45 {
#   background-color: #5bc0c0;
#   color: #000000;
# }
# #T_e0dcf_row2_col56 {
#   background-color: #1f2f87;
#   color: #f1f1f1;
# }
# #T_e0dcf_row2_col58 {
#   background-color: #253595;
#   color: #f1f1f1;
# }
# #T_e0dcf_row3_col10 {
#   background-color: #d9f0b3;
#   color: #000000;
# }
# #T_e0dcf_row3_col16 {
#   background-color: #1e8bbd;
#   color: #f1f1f1;
# }
# #T_e0dcf_row3_col17 {
#   background-color: #2262aa;
#   color: #f1f1f1;
# }
# #T_e0dcf_row3_col19 {
#   background-color: #b7e3b6;
#   color: #000000;
# }
# #T_e0dcf_row3_col23, #T_e0dcf_row3_col45 {
#   background-color: #234b9f;
#   color: #f1f1f1;
# }
# #T_e0dcf_row3_c

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 예시: 상위 3~5개 변수만 골라 시각화
selected_cols = numeric_cols[:5]

for col in selected_cols:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x='Segment', y=col, data=df_cleaned)
    plt.title(f'Segment별 {col} 분포')
    plt.tight_layout()
    plt.show()

# %%
import seaborn as sns

corr = df_cleaned[numeric_cols].corr()

plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', square=True)
plt.title("상관관계 히트맵 (결측 컬럼 제거 후)")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HR\AppData\Local\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
import pandas as pd
import os

# 1. 회원정보 파일 경로 리스트
member_file_paths = [
    "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/1.회원정보/201807_train_회원정보.parquet",
    "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/1.회원정보/201808_train_회원정보.parquet",
    "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/1.회원정보/201809_train_회원정보.parquet",
    "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/1.회원정보/201810_train_회원정보.parquet",
    "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/1.회원정보/201811_train_회원정보.parquet",
    "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/1.회원정보/201812_train_회원정보.parquet"
]

# 2. 마케팅정보 파일 경로 리스트
marketing_file_paths = [
    "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/7.마케팅정보/201807_train_마케팅정보.parquet",
    "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/7.마케팅정보/201808_train_마케팅정보.parquet",
    "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/7.마케팅정보/201809_train_마케팅정보.parquet",
    "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/7.마케팅정보/201810_train_마케팅정보.parquet",
    "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/7.마케팅정보/201811_train_마케팅정보.parquet",
    "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/7.마케팅정보/201812_train_마케팅정보.parquet"
]

# 3. 기준년월 컬럼 추가 및 병합 함수
def load_and_merge_parquet(file_paths):
    df_list = []
    for path in file_paths:
        df = pd.read_parquet(path)
        기준년월 = os.path.basename(path).split('_')[0]
        df['기준년월'] = 기준년월
        df_list.append(df)
    return pd.concat(df_list, ignore_index=True)

# 4. 데이터 로딩
member_df = load_and_merge_parquet(member_file_paths)
marketing_df = load_and_merge_parquet(marketing_file_paths)

# 5. Segment 컬럼 자동 탐색 및 숫자형 변환
segment_col_candidates = [col for col in member_df.columns if 'segment' in col.lower()]
print("사용 가능한 segment 컬럼 후보:", segment_col_candidates)
segment_col = segment_col_candidates[-1]

if member_df[segment_col].dtype == 'object':
    member_df[segment_col] = member_df[segment_col].astype('category').cat.codes

# 6. 두 DataFrame을 'ID'와 '기준년월' 기준으로 inner join (병합 아님, 동기화)
target_cols = ['ID', '기준년월', segment_col]
member_target = member_df[target_cols]
combined_df = pd.merge(member_target, marketing_df, on=['ID', '기준년월'], how='inner')

# 7. 분석 대상 numeric 컬럼만 선택
numeric_cols = [col for col in combined_df.select_dtypes(include=['int64', 'float64']).columns if col != segment_col]

# 8. 결측치 제거 및 std=0 컬럼 제거
clean_df = combined_df[numeric_cols + [segment_col]].dropna()
clean_df = clean_df.loc[:, clean_df.std() != 0]
numeric_cols = [col for col in numeric_cols if col in clean_df.columns]

# 9. 결측치 수 계산
missing_dict = {
    col: combined_df[col].isnull().sum()
    for col in numeric_cols
}

# 10. 이상치 수 계산 (IQR 기준)
outlier_dict = {}
for col in numeric_cols:
    Q1 = combined_df[col].quantile(0.25)
    Q3 = combined_df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = ((combined_df[col] < lower_bound) | (combined_df[col] > upper_bound)).sum()
    outlier_dict[col] = outliers

# 11. 상관계수 계산
corr_dict = {
    col: clean_df[segment_col].corr(clean_df[col])
    for col in numeric_cols
}

# 12. 결과 정리
corr_df = pd.DataFrame({
    '컬럼명': list(corr_dict.keys()),
    '상관계수': list(corr_dict.values()),
    '결측치 수': [missing_dict[col] for col in corr_dict.keys()],
    '이상치 수': [outlier_dict[col] for col in corr_dict.keys()]
})

corr_df = corr_df.sort_values(by='상관계수', key=abs, ascending=False)

# 13. 스타일링 출력
from IPython.display import display
styled = corr_df.style.background_gradient(cmap='coolwarm', subset=['상관계수']) \
                    .set_properties(**{'text-align': 'center'}) \
                    .set_table_styles([dict(selector='th', props=[('text-align', 'center')])])
display(styled)
# Out:
# 사용 가능한 segment 컬럼 후보: ['Segment']
# <style type="text/css">
# #T_8234b th {
#   text-align: center;
# }
# #T_8234b_row0_col0, #T_8234b_row0_col2, #T_8234b_row0_col3, #T_8234b_row1_col0, #T_8234b_row1_col2, #T_8234b_row1_col3, #T_8234b_row2_col0, #T_8234b_row2_col2, #T_8234b_row2_col3, #T_8234b_row3_col0, #T_8234b_row3_col2, #T_8234b_row3_col3, #T_8234b_row4_col0, #T_8234b_row4_col2, #T_8234b_row4_col3, #T_8234b_row5_col0, #T_8234b_row5_col2, #T_8234b_row5_col3, #T_8234b_row6_col0, #T_8234b_row6_col2, #T_8234b_row6_col3, #T_8234b_row7_col0, #T_8234b_row7_col2, #T_8234b_row7_col3, #T_8234b_row8_col0, #T_8234b_row8_col2, #T_8234b_row8_col3, #T_8234b_row9_col0, #T_8234b_row9_col2, #T_8234b_row9_col3, #T_8234b_row10_col0, #T_8234b_row10_col2, #T_8234b_row10_col3, #T_8234b_row11_col0, #T_8234b_row11_col2, #T_8234b_row11_col3, #T_8234b_row12_col0, #T_8234b_row12_col2, #T_8234b_row12_col3, #T_8234b_row13_col0, #T_8234b_row13_col2, #T_8234b_row13_col3, #T_8234b_row14_col0, #T_8234b_row14_col2, #T_8234b_row14_col3, #T_8234b_row15_col0, #T_8234b_row15_col2, #T_8234b_row15_col3, #T_8234b_row16_col0, #T_8234b_row16_col2, #T_8234b_row16_col3, #T_8234b_row17_col0, #T_8234b_row17_col2, #T_8234b_row17_col3, #T_8234b_row18_col0, #T_8234b_row18_col2, #T_8234b_row18_col3, #T_8234b_row19_col0, #T_8234b_row19_col2, #T_8234b_row19_col3, #T_8234b_row20_col0, #T_8234b_row20_col2, #T_8234b_row20_col3, #T_8234b_row21_col0, #T_8234b_row21_col2, #T_8234b_row21_col3, #T_8234b_row22_col0, #T_8234b_row22_col2, #T_8234b_row22_col3, #T_8234b_row23_col0, #T_8234b_row23_col2, #T_8234b_row23_col3, #T_8234b_row24_col0, #T_8234b_row24_col2, #T_8234b_row24_col3, #T_8234b_row25_col0, #T_8234b_row25_col2, #T_8234b_row25_col3, #T_8234b_row26_col0, #T_8234b_row26_col2, #T_8234b_row26_col3, #T_8234b_row27_col0, #T_8234b_row27_col2, #T_8234b_row27_col3, #T_8234b_row28_col0, #T_8234b_row28_col2, #T_8234b_row28_col3, #T_8234b_row29_col0, #T_8234b_row29_col2, #T_8234b_row29_col3, #T_8234b_row30_col0, #T_8234b_row30_col2, #T_8234b_row30_col3, #T_8234b_row31_col0, #T_8234b_row31_col2, #T_8234b_row31_col3, #T_8234b_row32_col0, #T_8234b_row32_col2, #T_8234b_row32_col3, #T_8234b_row33_col0, #T_8234b_row33_col2, #T_8234b_row33_col3, #T_8234b_row34_col0, #T_8234b_row34_col2, #T_8234b_row34_col3, #T_8234b_row35_col0, #T_8234b_row35_col2, #T_8234b_row35_col3, #T_8234b_row36_col0, #T_8234b_row36_col2, #T_8234b_row36_col3, #T_8234b_row37_col0, #T_8234b_row37_col2, #T_8234b_row37_col3 {
#   text-align: center;
# }
# #T_8234b_row0_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_8234b_row1_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_8234b_row2_col1 {
#   background-color: #4055c8;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_8234b_row3_col1 {
#   background-color: #7597f6;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_8234b_row4_col1 {
#   background-color: #f6a586;
#   color: #000000;
#   text-align: center;
# }
# #T_8234b_row5_col1 {
#   background-color: #f7af91;
#   color: #000000;
#   text-align: center;
# }
# #T_8234b_row6_col1 {
#   background-color: #f5c4ac;
#   color: #000000;
#   text-align: center;
# }
# #T_8234b_row7_col1 {
#   background-color: #a7c5fe;
#   color: #000000;
#   text-align: center;
# }
# #T_8234b_row8_col1 {
#   background-color: #eed0c0;
#   color: #000000;
#   text-align: center;
# }
# #T_8234b_row9_col1, #T_8234b_row10_col1 {
#   background-color: #b6cefa;
#   color: #000000;
#   text-align: center;
# }
# #T_8234b_row11_col1 {
#   background-color: #ead4c8;
#   color: #000000;
#   text-align: center;
# }
# #T_8234b_row12_col1 {
#   background-color: #ead5c9;
#   color: #000000;
#   text-align: center;
# }
# #T_8234b_row13_col1 {
#   background-color: #bed2f6;
#   color: #000000;
#   text-align: center;
# }
# #T_8234b_row14_col1 {
#   background-color: #c1d4f4;
#   color: #000000;
#   text-align: center;
# }
# #T_8234b_row15_col1 {
#   background-color: #c4d5f3;
#   color: #000000;
#   text-align: center;
# }
# #T_8234b_row16_col1 {
#   background-color: #e5d8d1;
#   color: #000000;
#   text-align: center;
# }
# #T_8234b_row17_col1 {
#   background-color: #c6d6f1;
#   color: #000000;
#   text-align: center;
# }
# #T_8234b_row18_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
#   text-align: center;
# }
# #T_8234b_row19_col1 {
#   background-color: #e0dbd8;
#   color: #000000;
#   text-align: center;
# }
# #T_8234b_row20_col1 {
#   background-color: #cad8ef;
#   color: #000000;
#   text-align: center;
# }
# #T_8234b_row21_col1 {
#   background-color: #ccd9ed;
#   color: #000000;
#   text-align: center;
# }
# #T_8234b_row22_col1 {
#   background-color: #dddcdc;
#   color: #000000;
#   text-align: center;
# }
# #T_8234b_row23_col1, #T_8234b_row24_col1 {
#   background-color: #cedaeb;
#   color: #000000;
#   text-align: center;
# }
# #T_8234b_row25_col1, #T_8234b_row26_col1 {
#   background-color: #dbdcde;
#   color: #000000;
#   text-align: center;
# }
# #T_8234b_row27_col1 {
#   background-color: #cfdaea;
#   color: #000000;
#   text-align: center;
# }
# #T_8234b_row28_col1, #T_8234b_row29_col1, #T_8234b_row30_col1 {
#   background-color: #d1dae9;
#   color: #000000;
#   text-align: center;
# }
# #T_8234b_row31_col1 {
#   background-color: #d2dbe8;
#   color: #000000;
#   text-align: center;
# }
# #T_8234b_row32_col1 {
#   background-color: #d4dbe6;
#   color: #000000;
#   text-align: center;
# }
# #T_8234b_row33_col1, #T_8234b_row34_col1, #T_8234b_row35_col1, #T_8234b_row36_col1 {
#   background-color: #d6dce4;
#   color: #000000;
#   text-align: center;
# }
# #T_8234b_row37_col1 {
#   background-color: #d5dbe5;
#   color: #000000;
#   text-align: center;
# }
# </style>
# <table id="T_8234b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8234b_level0_col0" class="col_heading level0 col0" >컬럼명</th>
#       <th id="T_8234b_level0_col1" class="col_heading level0 col1" >상관계수</th>
#       <th id="T_8234b_level0_col2" class="col_heading level0 col2" >결측치 수</th>
#       <th id="T_8234b_level0_col3" class="col_heading level0 col3" >이상치 수</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8234b_level0_row0" class="row_heading level0 row0" >20</th>
#       <td id="T_8234b_row0_col0" class="data row0 col0" >컨택건수_이용유도_TM_R6M</td>
#       <td id="T_8234b_row0_col1" class="data row0 col1" >0.149037</td>
#       <td id="T_8234b_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_8234b_row0_col3" class="data row0 col3" >103328</td>
#     </tr>
#     <tr>
#       <th id="T_8234b_level0_row1" class="row_heading level0 row1" >30</th>
#       <td id="T_8234b_row1_col0" class="data row1 col0" >컨택건수_이용유도_EM_R6M</td>
#       <td id="T_8234b_row1_col1" class="data row1 col1" >-0.133304</td>
#       <td id="T_8234b_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_8234b_row1_col3" class="data row1 col3" >399903</td>
#     </tr>
#     <tr>
#       <th id="T_8234b_level0_row2" class="row_heading level0 row2" >11</th>
#       <td id="T_8234b_row2_col0" class="data row2 col0" >컨택건수_이용유도_EM_B0M</td>
#       <td id="T_8234b_row2_col1" class="data row2 col1" >-0.127584</td>
#       <td id="T_8234b_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_8234b_row2_col3" class="data row2 col3" >349290</td>
#     </tr>
#     <tr>
#       <th id="T_8234b_level0_row3" class="row_heading level0 row3" >14</th>
#       <td id="T_8234b_row3_col0" class="data row3 col0" >컨택건수_이용유도_청구서_B0M</td>
#       <td id="T_8234b_row3_col1" class="data row3 col1" >-0.081478</td>
#       <td id="T_8234b_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_8234b_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8234b_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_8234b_row4_col0" class="data row4 col0" >컨택건수_이용유도_TM_B0M</td>
#       <td id="T_8234b_row4_col1" class="data row4 col1" >0.069907</td>
#       <td id="T_8234b_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_8234b_row4_col3" class="data row4 col3" >64948</td>
#     </tr>
#     <tr>
#       <th id="T_8234b_level0_row5" class="row_heading level0 row5" >34</th>
#       <td id="T_8234b_row5_col0" class="data row5 col0" >컨택건수_이용유도_인터넷_R6M</td>
#       <td id="T_8234b_row5_col1" class="data row5 col1" >0.062556</td>
#       <td id="T_8234b_row5_col2" class="d

# %%
corr_filtered = corr_df[abs(corr_df['상관계수']) >= 0.3]
print("선별된 변수 수:", len(corr_filtered))
display(corr_filtered)
# Out:
# 선별된 변수 수: 0
# Empty DataFrame
# Columns: [컬럼명, 상관계수, 결측치 수, 이상치 수]
# Index: []
