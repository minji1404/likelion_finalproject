# %%
import pandas as pd
import os

# 1. 회원정보 파일 경로 리스트
member_file_paths = [
    "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/1.회원정보/201807_train_회원정보.parquet",
    "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/1.회원정보/201808_train_회원정보.parquet",
    "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/1.회원정보/201809_train_회원정보.parquet",
    "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/1.회원정보/201810_train_회원정보.parquet",
    "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/1.회원정보/201811_train_회원정보.parquet",
    "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/1.회원정보/201812_train_회원정보.parquet"
]

# 2. 마케팅정보 파일 경로 리스트
marketing_file_paths = [
    "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/8.성과정보/201807_train_성과정보.parquet",
    "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/8.성과정보/201808_train_성과정보.parquet",
    "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/8.성과정보/201809_train_성과정보.parquet",
    "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/8.성과정보/201810_train_성과정보.parquet",
    "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/8.성과정보/201811_train_성과정보.parquet",
    "C:/Users/HR/Desktop/workspace/파이널프로젝트/open/train/8.성과정보/201812_train_성과정보.parquet"
]

# 3. 기준년월 컬럼 추가 및 병합 함수
def load_and_merge_parquet(file_paths):
    df_list = []
    for path in file_paths:
        df = pd.read_parquet(path)
        기준년월 = os.path.basename(path).split('_')[0]
        df['기준년월'] = 기준년월
        df_list.append(df)
    return pd.concat(df_list, ignore_index=True)

# 4. 데이터 로딩
member_df = load_and_merge_parquet(member_file_paths)
marketing_df = load_and_merge_parquet(marketing_file_paths)

# 5. Segment 컬럼 자동 탐색 및 숫자형 변환
segment_col_candidates = [col for col in member_df.columns if 'segment' in col.lower()]
print("사용 가능한 segment 컬럼 후보:", segment_col_candidates)
segment_col = segment_col_candidates[-1]

if member_df[segment_col].dtype == 'object':
    member_df[segment_col] = member_df[segment_col].astype('category').cat.codes

# 6. 두 DataFrame을 'ID'와 '기준년월' 기준으로 inner join (병합 아님, 동기화)
target_cols = ['ID', '기준년월', segment_col]
member_target = member_df[target_cols]
combined_df = pd.merge(member_target, marketing_df, on=['ID', '기준년월'], how='inner')

# 7. 분석 대상 numeric 컬럼만 선택
numeric_cols = [col for col in combined_df.select_dtypes(include=['int64', 'float64']).columns if col != segment_col]

# 8. 결측치 제거 및 std=0 컬럼 제거
clean_df = combined_df[numeric_cols + [segment_col]].dropna()
clean_df = clean_df.loc[:, clean_df.std() != 0]
numeric_cols = [col for col in numeric_cols if col in clean_df.columns]

# 9. 결측치 수 계산
missing_dict = {
    col: combined_df[col].isnull().sum()
    for col in numeric_cols
}

# 10. 이상치 수 계산 (IQR 기준)
outlier_dict = {}
for col in numeric_cols:
    Q1 = combined_df[col].quantile(0.25)
    Q3 = combined_df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = ((combined_df[col] < lower_bound) | (combined_df[col] > upper_bound)).sum()
    outlier_dict[col] = outliers

# 11. 상관계수 계산
corr_dict = {
    col: clean_df[segment_col].corr(clean_df[col])
    for col in numeric_cols
}

# 12. 결과 정리
corr_df = pd.DataFrame({
    '컬럼명': list(corr_dict.keys()),
    '상관계수': list(corr_dict.values()),
    '결측치 수': [missing_dict[col] for col in corr_dict.keys()],
    '이상치 수': [outlier_dict[col] for col in corr_dict.keys()]
})

corr_df = corr_df.sort_values(by='상관계수', key=abs, ascending=False)

# 13. 스타일링 출력
from IPython.display import display
styled = corr_df.style.background_gradient(cmap='coolwarm', subset=['상관계수']) \
                    .set_properties(**{'text-align': 'center'}) \
                    .set_table_styles([dict(selector='th', props=[('text-align', 'center')])])
display(styled)
# Out:
# 사용 가능한 segment 컬럼 후보: ['Segment']
# <style type="text/css">
# #T_5e89c th {
#   text-align: center;
# }
# #T_5e89c_row0_col0, #T_5e89c_row0_col2, #T_5e89c_row0_col3, #T_5e89c_row1_col0, #T_5e89c_row1_col2, #T_5e89c_row1_col3, #T_5e89c_row2_col0, #T_5e89c_row2_col2, #T_5e89c_row2_col3, #T_5e89c_row3_col0, #T_5e89c_row3_col2, #T_5e89c_row3_col3, #T_5e89c_row4_col0, #T_5e89c_row4_col2, #T_5e89c_row4_col3, #T_5e89c_row5_col0, #T_5e89c_row5_col2, #T_5e89c_row5_col3, #T_5e89c_row6_col0, #T_5e89c_row6_col2, #T_5e89c_row6_col3, #T_5e89c_row7_col0, #T_5e89c_row7_col2, #T_5e89c_row7_col3, #T_5e89c_row8_col0, #T_5e89c_row8_col2, #T_5e89c_row8_col3, #T_5e89c_row9_col0, #T_5e89c_row9_col2, #T_5e89c_row9_col3, #T_5e89c_row10_col0, #T_5e89c_row10_col2, #T_5e89c_row10_col3, #T_5e89c_row11_col0, #T_5e89c_row11_col2, #T_5e89c_row11_col3, #T_5e89c_row12_col0, #T_5e89c_row12_col2, #T_5e89c_row12_col3, #T_5e89c_row13_col0, #T_5e89c_row13_col2, #T_5e89c_row13_col3, #T_5e89c_row14_col0, #T_5e89c_row14_col2, #T_5e89c_row14_col3, #T_5e89c_row15_col0, #T_5e89c_row15_col2, #T_5e89c_row15_col3, #T_5e89c_row16_col0, #T_5e89c_row16_col2, #T_5e89c_row16_col3, #T_5e89c_row17_col0, #T_5e89c_row17_col2, #T_5e89c_row17_col3, #T_5e89c_row18_col0, #T_5e89c_row18_col2, #T_5e89c_row18_col3, #T_5e89c_row19_col0, #T_5e89c_row19_col2, #T_5e89c_row19_col3, #T_5e89c_row20_col0, #T_5e89c_row20_col2, #T_5e89c_row20_col3, #T_5e89c_row21_col0, #T_5e89c_row21_col2, #T_5e89c_row21_col3, #T_5e89c_row22_col0, #T_5e89c_row22_col2, #T_5e89c_row22_col3, #T_5e89c_row23_col0, #T_5e89c_row23_col2, #T_5e89c_row23_col3, #T_5e89c_row24_col0, #T_5e89c_row24_col2, #T_5e89c_row24_col3, #T_5e89c_row25_col0, #T_5e89c_row25_col2, #T_5e89c_row25_col3, #T_5e89c_row26_col0, #T_5e89c_row26_col2, #T_5e89c_row26_col3, #T_5e89c_row27_col0, #T_5e89c_row27_col2, #T_5e89c_row27_col3, #T_5e89c_row28_col0, #T_5e89c_row28_col2, #T_5e89c_row28_col3, #T_5e89c_row29_col0, #T_5e89c_row29_col2, #T_5e89c_row29_col3, #T_5e89c_row30_col0, #T_5e89c_row30_col2, #T_5e89c_row30_col3, #T_5e89c_row31_col0, #T_5e89c_row31_col2, #T_5e89c_row31_col3, #T_5e89c_row32_col0, #T_5e89c_row32_col2, #T_5e89c_row32_col3, #T_5e89c_row33_col0, #T_5e89c_row33_col2, #T_5e89c_row33_col3, #T_5e89c_row34_col0, #T_5e89c_row34_col2, #T_5e89c_row34_col3, #T_5e89c_row35_col0, #T_5e89c_row35_col2, #T_5e89c_row35_col3, #T_5e89c_row36_col0, #T_5e89c_row36_col2, #T_5e89c_row36_col3, #T_5e89c_row37_col0, #T_5e89c_row37_col2, #T_5e89c_row37_col3, #T_5e89c_row38_col0, #T_5e89c_row38_col2, #T_5e89c_row38_col3, #T_5e89c_row39_col0, #T_5e89c_row39_col2, #T_5e89c_row39_col3, #T_5e89c_row40_col0, #T_5e89c_row40_col2, #T_5e89c_row40_col3, #T_5e89c_row41_col0, #T_5e89c_row41_col2, #T_5e89c_row41_col3, #T_5e89c_row42_col0, #T_5e89c_row42_col2, #T_5e89c_row42_col3, #T_5e89c_row43_col0, #T_5e89c_row43_col2, #T_5e89c_row43_col3, #T_5e89c_row44_col0, #T_5e89c_row44_col2, #T_5e89c_row44_col3, #T_5e89c_row45_col0, #T_5e89c_row45_col2, #T_5e89c_row45_col3, #T_5e89c_row46_col0, #T_5e89c_row46_col2, #T_5e89c_row46_col3 {
#   text-align: center;
# }
# #T_5e89c_row0_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_5e89c_row1_col1 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_5e89c_row2_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_5e89c_row3_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_5e89c_row4_col1 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_5e89c_row5_col1 {
#   background-color: #89acfd;
#   color: #000000;
#   text-align: center;
# }
# #T_5e89c_row6_col1 {
#   background-color: #8db0fe;
#   color: #000000;
#   text-align: center;
# }
# #T_5e89c_row7_col1 {
#   background-color: #93b5fe;
#   color: #000000;
#   text-align: center;
# }
# #T_5e89c_row8_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_5e89c_row9_col1 {
#   background-color: #b70d28;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_5e89c_row10_col1 {
#   background-color: #d55042;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_5e89c_row11_col1 {
#   background-color: #d95847;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_5e89c_row12_col1 {
#   background-color: #e26952;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_5e89c_row13_col1, #T_5e89c_row14_col1, #T_5e89c_row15_col1 {
#   background-color: #e36c55;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_5e89c_row16_col1, #T_5e89c_row17_col1 {
#   background-color: #e46e56;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_5e89c_row18_col1 {
#   background-color: #e8d6cc;
#   color: #000000;
#   text-align: center;
# }
# #T_5e89c_row19_col1 {
#   background-color: #ead5c9;
#   color: #000000;
#   text-align: center;
# }
# #T_5e89c_row20_col1 {
#   background-color: #e7745b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_5e89c_row21_col1 {
#   background-color: #ead4c8;
#   color: #000000;
#   text-align: center;
# }
# #T_5e89c_row22_col1 {
#   background-color: #ebd3c6;
#   color: #000000;
#   text-align: center;
# }
# #T_5e89c_row23_col1 {
#   background-color: #ed8366;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_5e89c_row24_col1, #T_5e89c_row25_col1 {
#   background-color: #f18f71;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_5e89c_row26_col1, #T_5e89c_row27_col1 {
#   background-color: #f39778;
#   color: #000000;
#   text-align: center;
# }
# #T_5e89c_row28_col1 {
#   background-color: #f5c1a9;
#   color: #000000;
#   text-align: center;
# }
# #T_5e89c_row29_col1, #T_5e89c_row30_col1, #T_5e89c_row31_col1 {
#   background-color: #f49a7b;
#   color: #000000;
#   text-align: center;
# }
# #T_5e89c_row32_col1 {
#   background-color: #f59c7d;
#   color: #000000;
#   text-align: center;
# }
# #T_5e89c_row33_col1, #T_5e89c_row34_col1 {
#   background-color: #f59f80;
#   color: #000000;
#   text-align: center;
# }
# #T_5e89c_row35_col1 {
#   background-color: #f6a283;
#   color: #000000;
#   text-align: center;
# }
# #T_5e89c_row36_col1, #T_5e89c_row37_col1 {
#   background-color: #f6a385;
#   color: #000000;
#   text-align: center;
# }
# #T_5e89c_row38_col1 {
#   background-color: #f6a586;
#   color: #000000;
#   text-align: center;
# }
# #T_5e89c_row39_col1, #T_5e89c_row40_col1, #T_5e89c_row41_col1, #T_5e89c_row42_col1 {
#   background-color: #f7a688;
#   color: #000000;
#   text-align: center;
# }
# #T_5e89c_row43_col1, #T_5e89c_row44_col1 {
#   background-color: #f7a98b;
#   color: #000000;
#   text-align: center;
# }
# #T_5e89c_row45_col1 {
#   background-color: #f7aa8c;
#   color: #000000;
#   text-align: center;
# }
# #T_5e89c_row46_col1 {
#   background-color: #f7ac8e;
#   color: #000000;
#   text-align: center;
# }
# </style>
# <table id="T_5e89c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e89c_level0_col0" class="col_heading level0 col0" >컬럼명</th>
#       <th id="T_5e89c_level0_col1" class="col_heading level0 col1" >상관계수</th>
#       <th id="T_5e89c_level0_col2" class="col_heading level0 col2" >결측치 수</th>
#       <th id="T_5e89c_level0_col3" class="col_heading level0 col3" >이상치 수</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e89c_level0_row0" class="row_heading level0 row0" >33</th>
#       <td id="T_5e89c_row0_col0" class="data row0 col0" >잔액_신판ca최대한도소진율_r6m</td>
#       <td id="T_5e89c_row0_col1" class="data row0 col1" >-0.224311</td>
#       <td id="T_5e89c_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_5e89c_row0_col3" class="data row0 col3" >169711</td>
#     </tr>
#     <tr>
#       <th id="T_5e89c_level0_row1" class="row_heading level0 row1" >35</th>
#       <td id="T_5e89c_row1_col0" class="data row1 col0" >잔액_신판ca최대한도소진율_r3m</td>
#       <td id="T_5e89c_row1_col1" class="data row1 col1" >-0.219062</td>
#       <td id="T_5e89c_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_5e89c_row1_col3" class="data row1 col3" >208494</td>
#     </tr>
#     <tr>
#       <th id="T_5e89c_level0_row2" class="row_heading level0 row2" >34</th>
#       <td id="T_5e89c_row2_col0" class="data row2 col0" >잔액_신판ca평균한도소진율_r3m</td>
#       <td id="T_5e89c_row2_col1" class="data row2 col1" >-0.216028</td>
#       <td id="T_5e89c_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_5e89c_row2_col3" class="data row2 col3"

# %%
corr_filtered = corr_df[abs(corr_df['상관계수']) >= 0.3]
print("선별된 변수 수:", len(corr_filtered))
display(corr_filtered)
# Out:
# 선별된 변수 수: 0
# Empty DataFrame
# Columns: [컬럼명, 상관계수, 결측치 수, 이상치 수]
# Index: []
